# %%
# 1) Install dependencies
# %pip install -q numpy scipy pytest
# %pip install -e ./Python
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# ERROR: ./Python is not a valid editable requirement. It should either be a path to a local project or a VCS URL (beginning with bzr+http, bzr+https, bzr+ssh, bzr+sftp, bzr+ftp, bzr+lp, bzr+file, git+http, git+https, git+ssh, git+git, git+file, hg+file, hg+http, hg+https, hg+ssh, hg+static-http, svn+ssh, svn+http, svn+https, svn+svn, svn+file).

# %%
# 2) Necessary imports
from pathlib import Path
import numpy as np
from src.driver import solve_from_inp

# %%
# 3) Read the input file
inp_path = Path('../../inputs/plate_vibration_python.inp').resolve()
assert inp_path.exists(), f'Missing input file: {inp_path}'
inp_path
# Out:
# WindowsPath('C:/Users/arpan/OneDrive/Desktop/FEM2D/inputs/plate_vibration_python.inp')

# %%
# 4) Run relevant Python workflow from INP -> solve -> write Fortran-style TXT
out_path = Path('../../outputs/plate_vibration_python_from_notebook.txt').resolve()
u, field, cfg = solve_from_inp(str(inp_path), output_txt_path=str(out_path))
print('Title      :', cfg.title)
print('ITYPE      :', cfg.problem_type.itype)
print('NEQ        :', cfg.neq)
print('Output TXT :', out_path)
print('Center u   :', float(field[12, 0]))
print('Center v   :', float(field[12, 1]))
# Out:
# Title      : Rectangular plate vibration with clamped edges (PYTHON)
# ITYPE      : 2
# NEQ        : 50
# Output TXT : C:\Users\arpan\OneDrive\Desktop\FEM2D\outputs\plate_vibration_python_from_notebook.txt
# Center u   : -0.127889753685396
# Center v   : -0.005503351224260925

# %%
# 5) Show final text output in this output cell
txt = out_path.read_text(encoding='utf-8')
print(txt)
# Out:
# Rectangular plate vibration with clamped edges (PYTHON)
#   _____________________________________________________________________________
#
#      *TIME* = 1.00000E+00     Time Step Number = 10
#
#      S O L U T I O N :
#
#   _____________________________________________________________________________
#
#     Node    x-coord.      y-coord.     Value of u     Value of v
#   _____________________________________________________________________________
#
#        1   0.00000E+00   0.00000E+00   0.00000E+00   -1.35149E-01
#        2   2.50000E-01   0.00000E+00   0.00000E+00   -8.95680E-02
#        3   5.00000E-01   0.00000E+00   0.00000E+00   -5.50336E-03
#        4   7.50000E-01   0.00000E+00   0.00000E+00   7.85612E-02
#        5   1.00000E+00   0.00000E+00   0.00000E+00   1.24142E-01
#        6   0.00000E+00   2.50000E-01   0.00000E+00   -1.63689E-01
#        7   2.50000E-01   2.50000E-01   0.00000E+00   -9.01372E-02
#        8   5.00000E-01   2.50000E-01   0.00000E+00   -5.50335E-03
#        9   7.50000E-01   2.50000E-01   0.00000E+00   7.91305E-02
#       10   1.00000E+00   2.50000E-01   0.00000E+00   1.52683E-01
#       11   0.00000E+00   5.00000E-01   -1.31357E-01   -2.01052E-01
#       12   2.50000E-01   5.00000E-01   -1.27200E-01   -9.51739E-02
#       13   5.00000E-01   5.00000E-01   -1.27890E-01   -5.50335E-03
#       14   7.50000E-01   5.00000E-01   -1.27200E-01   8.41671E-02
#       15   1.00000E+00   5.00000E-01   -1.31357E-01   1.90045E-01
#       16   0.00000E+00   7.50000E-01   -2.54112E-01   -2.10906E-01
#       17   2.50000E-01   7.50000E-01   -2.52585E-01   -1.01992E-01
#       18   5.00000E-01   7.50000E-01   -2.51263E-01   -5.50335E-03
#       19   7.50000E-01   7.50000E-01   -2.52585E-01   9.09852E-02
#       20   1.00000E+00   7.50000E-01   -2.54112E-01   1.99900E-01
#       21   0.00000E+00   1.00000E+00   -3.66165E-01   -2.12298E-01
#       22   2.50000E-01   1.00000E+00   -3.63628E-01   -1.04778E-01
#       23   5.00000E-01   1.00000E+00   -3.61302E-01   -5.50337E-03
#       24   7.50000E-01   1.00000E+00   -3.63628E-01   9.37708E-02
#       25   1.00000E+00   1.00000E+00   -3.66165E-01   2.01292E-01
#   _____________________________________________________________________________
